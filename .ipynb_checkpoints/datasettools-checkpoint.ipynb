# %% [markdown]
# # DataSet Preparation Utils
# by Wael Radwan

# %% [markdown]
# #### Library used to prepare datasets from data
# continans various tools to prepare the training dataset and testing dataset
#
# mainly used to randomize files of the dataset
# divide the dataset into traininig and testing dataset
# randomize the test files
#
# <b> the main idea here is to load the dataset into classified directories then use this utility to create train/test dataset with the randomization </b>

# %%
import os
import re
import random
import ntpath
import shutil
import pandas as pd

# %% [markdown]
# #### Input description
# input to this tool is a dataset of files divided into classes in the following order
# - class_1:
#     - file_1
#     - file_2
#     - .
#     - .
# - class_2
#     - file_1
#     - file_2
#     - .
#     - .
# - .
# - .
#
#
# - class_n
#     - file_1
#     - file_2
#     - .
#     - .

# %% [markdown]
# #### Output description
# output shoud be the data divided into train and test sets  in the following order
#
# - train
#     - class_1_001
#     - class_1_002
#     - .
#     - .
#     - class_2_001
#     - class_2_002
#     - .
#     - .
#     - .
#     - .
#     - class_n_001
#     - class_n_002
#     - .
#     - .
#
# - test
#     - class_1_001
#     - class_1_002
#     - .
#     - .
#     - class_2_001
#     - class_2_002
#     - .
#     - .
#     - .
#     - .
#     - class_n_001
#     - class_n_002
#     - .
#     - .
#
#     - class_label.csv (a csv file contains the filename and the label so it can be used for testing comparison)

# %% [markdown]
# #### create panda from the files dataset
# mainly used for the test dataset to generate the file name and the label based on the label criteria
# randomize is set to true if the files are ranomized in the dataset instead of ordered

# %%
def list_files_with_labels(path, randomize=False):
    files = sorted(os.listdir(path))
    file = [os.path.splitext(x)[0] for x in files]
    ext = [os.path.splitext(x)[-1] for x in files]
    class_name = ntpath.basename(path)
    if (randomize) :
        random.shuffle(files)

    # create panda dataframe for file sorted by their name

    datset = pd.DataFrame(data={"file":file,"ext":ext, "label":class_name})
    datset = datset[['file', 'ext', 'label']]
    return dataset

# %%
 dataset = list_files_with_labels( path,randomize=True)

# %% [markdown]
# #### create list of the dataset with new name for each file based on a sequence
# randomize or order the files in the dataset then create a new name based on sequence number
#
# - path      : path to the class
# - seqlen    : is the lenght of the sequence so if seqlen = 3 the new file names follow the sequence 001, 002, 003, ...
# - randomize : either to randomize the files in the class set or not (default is not to randomize)
# - retrun panda structure with new file name

# %%
def list_with_new_file_name_seq(path,  seqlen, randomize=False,):
    df = []  
    dataset = list_files_with_labels( path)
    df = dataset.sample(frac=1).reset_index(drop=True)
    df['newfilename'] = (df.index + 1).astype(str).str.zfill(seqlen) + df.ext
    
    # df.index = df.index.map(str) 
    return df

# %%
data = list_with_new_file_name_seq( path,3)

# %%
data
# Out:
#                             files   ext labels newfilename
# 0                112-Al-ikhlas_87  .mp3    999     001.mp3
# 1             112_uP_bY_mUSLEm_58  .mp3    999     002.mp3
# 2   112_uP_bY_mUSLEm.Ettounssi_18  .mp3    999     003.mp3
# 3                112-Al-ikhlas_38  .mp3    999     004.mp3
# 4                          112_58  .mp3    999     005.mp3
# 5             112_uP_bY_mUSLEm_18  .mp3    999     006.mp3
# 6                         112_158  .mp3    999     007.mp3
# 7                          112_89  .mp3    999     008.mp3
# 8                112-Al-ikhlas_28  .mp3    999     009.mp3
# 9             112_uP_bY_mUSLEm_28  .mp3    999     010.mp3
# 10                         112_84  .mp3    999     011.mp3
# 11                        112_189  .mp3    999     012.mp3
# 12                         112_87  .mp3    999     013.mp3
# 13                         112_88  .mp3    999     014.mp3
# 14                         112_48  .mp3    999     015.mp3
# 15                         112_28  .mp3    999     016.mp3
# 16               112-Al-ikhlas_48  .mp3    999     017.mp3
# 17                         112_98  .mp3    999     018.mp3
# 18                         112_80  .mp3    999     019.mp3
# 19                        112_186  .mp3    999     020.mp3
# 20                        112_181  .mp3    999     021.mp3
# 21                         112_38  .mp3    999     022.mp3
# 22                         112_82  .mp3    999     023.mp3
# 23                        112_185  .mp3    999     024.mp3
# 24                        112_238  .mp3    999     025.mp3
# 25                         112_86  .mp3    999     026.mp3
# 26                         112_83  .mp3    999     027.mp3
# 27                        112_228  .mp3    999     028.mp3
# 28                        112_198  .mp3    999     029.mp3
# 29                         112_18  .mp3    999     030.mp3
# 30                        112_208  .mp3    999     031.mp3
# 31            112_uP_bY_mUSLEm_48  .mp3    999     032.mp3
# 32             112_uP_bY_mUSLEm_8  .mp3    999     033.mp3
# 33                        112_187  .mp3    999     034.mp3
# 34                        112_184  .mp3    999     035.mp3
# 35                        112_138  .mp3    999     036.mp3
# 36                112-Al-ikhlas_8  .mp3    999     037.mp3
# 37               112-Al-ikhlas_84  .mp3    999     038.mp3
# 38                        112_248  .mp3    999     039.mp3
# 39               112-Al-ikhlas_98  .mp3    999     040.mp3
# 40                        112_182  .mp3    999     041.mp3
# 41  112_uP_bY_mUSLEm.Ettounssi_38  .mp3    999     042.mp3
# 42  112_uP_bY_mUSLEm.Ettounssi_28  .mp3    999     043.mp3
# 43            112_uP_bY_mUSLEm_38  .mp3    999     044.mp3
# 44                         112_68  .mp3    999     045.mp3
# 45                         112_78  .mp3    999     046.mp3
# 46                        112_180  .mp3    999     047.mp3
# 47                        112_218  .mp3    999     048.mp3
# 48               112-Al-ikhlas_88  .mp3    999     049.mp3
# 49                        112_183  .mp3    999     050.mp3
# 50                        112_108  .mp3    999     051.mp3
# 51                        112_148  .mp3    999     052.mp3
# 52                        112_128  .mp3    999     053.mp3
# 53               112-Al-ikhlas_58  .mp3    999     054.mp3
# 54                        112_178  .mp3    999     055.mp3
# 55                        112_168  .mp3    999     056.mp3
# 56               112-Al-ikhlas_80  .mp3    999     057.mp3
# 57                         112_81  .mp3    999     058.mp3
# 58                        112_188  .mp3    999     059.mp3

# %% [markdown]
# #### Rename files
# after creating the dataframe with proposed renamed files then do the rename files in the dataset
# then rename all the files to _tmp files in order not to overwrite files that already exist

# %%
def rename_files_dataset(path, seqlen):
    # first list the files in the input dir and put the porposed name in the dataframe
    data = list_with_new_file_name_seq( path,seqlen)

    
    # track the seq
    i = 1
    
    # keep the track of the new file names in a list in order to be used later
    tmp_file_names = []
    
    # first rename the files with _tmp in order not to overwrite files 
    # and keep the renamed files in the list 
    # then use the list to remove _tmp files
    for index, row in data.iterrows():
        tmp_file_name = path+'/'+row['newfilename'] + '_tmp'
        oring_file_name = path+'/'+row['files'] + row['ext']
        print('rename %s to %s'  % (oring_file_name, tmp_file_name) )
        tmp_file_names.append(tmp_file_name)
        
        
    for temp_file in tmp_file_names:
        print('rename %s to %s'  % (temp_file, temp_file.rsplit('_tmp', -1)[0]) )
    return

# %%
rename_files_dataset(path , 4)
# Out:
# rename /ds/dataset/quran/999/112_83.mp3 to /ds/dataset/quran/999/0001.mp3_tmp
# rename /ds/dataset/quran/999/112-Al-ikhlas_58.mp3 to /ds/dataset/quran/999/0002.mp3_tmp
# rename /ds/dataset/quran/999/112_108.mp3 to /ds/dataset/quran/999/0003.mp3_tmp
# rename /ds/dataset/quran/999/112-Al-ikhlas_87.mp3 to /ds/dataset/quran/999/0004.mp3_tmp
# rename /ds/dataset/quran/999/112_87.mp3 to /ds/dataset/quran/999/0005.mp3_tmp
# rename /ds/dataset/quran/999/112_182.mp3 to /ds/dataset/quran/999/0006.mp3_tmp
# rename /ds/dataset/quran/999/112_89.mp3 to /ds/dataset/quran/999/0007.mp3_tmp
# rename /ds/dataset/quran/999/112-Al-ikhlas_84.mp3 to /ds/dataset/quran/999/0008.mp3_tmp
# rename /ds/dataset/quran/999/112_58.mp3 to /ds/dataset/quran/999/0009.mp3_tmp
# rename /ds/dataset/quran/999/112-Al-ikhlas_38.mp3 to /ds/dataset/quran/999/0010.mp3_tmp
# rename /ds/dataset/quran/999/112_84.mp3 to /ds/dataset/quran/999/0011.mp3_tmp
# rename /ds/dataset/quran/999/112_186.mp3 to /ds/dataset/quran/999/0012.mp3_tmp
# rename /ds/dataset/quran/999/112_183.mp3 to /ds/dataset/quran/999/0013.mp3_tmp
# rename /ds/dataset/quran/999/112_138.mp3 to /ds/dataset/quran/999/0014.mp3_tmp
# rename /ds/dataset/quran/999/112_188.mp3 to /ds/dataset/quran/999/0015.mp3_tmp
# rename /ds/dataset/quran/999/112_80.mp3 to /ds/dataset/quran/999/0016.mp3_tmp
# rename /ds/dataset/quran/999/112_uP_bY_mUSLEm_18.mp3 to /ds/dataset/quran/999/0017.mp3_tmp
# rename /ds/dataset/quran/999/112-Al-ikhlas_88.mp3 to /ds/dataset/quran/999/0018.mp3_tmp
# rename /ds/dataset/quran/999/112_238.mp3 to /ds/dataset/quran/999/0019.mp3_tmp
# rename /ds/dataset/quran/999/112_198.mp3 to /ds/dataset/quran/999/0020.mp3_tmp
# rename /ds/dataset/quran/999/112_228.mp3 to /ds/dataset/quran/999/0021.mp3_tmp
# rename /ds/dataset/quran/999/112_uP_bY_mUSLEm_58.mp3 to /ds/dataset/quran/999/0022.mp3_tmp
# rename /ds/dataset/quran/999/112_78.mp3 to /ds/dataset/quran/999/0023.mp3_tmp
# rename /ds/dataset/quran/999/112_128.mp3 to /ds/dataset/quran/999/0024.mp3_tmp
# rename /ds/dataset/quran/999/112_28.mp3 to /ds/dataset/quran/999/0025.mp3_tmp
# rename /ds/dataset/quran/999/112_uP_bY_mUSLEm.Ettounssi_18.mp3 to /ds/dataset/quran/999/0026.mp3_tmp
# rename /ds/dataset/quran/999/112_98.mp3 to /ds/dataset/quran/999/0027.mp3_tmp
# rename /ds/dataset/quran/999/112_189.mp3 to /ds/dataset/quran/999/0028.mp3_tmp
# rename /ds/dataset/quran/999/112-Al-ikhlas
# rename /ds/dataset/quran/999/0030.mp3_tmp to /ds/dataset/quran/999/0030.mp3
# rename /ds/dataset/quran/999/0031.mp3_tmp to /ds/dataset/quran/999/0031.mp3
# rename /ds/dataset/quran/999/0032.mp3_tmp to /ds/dataset/quran/999/0032.mp3
# rename /ds/dataset/quran/999/0033.mp3_tmp to /ds/dataset/quran/999/0033.mp3
# rename /ds/dataset/quran/999/0034.mp3_tmp to /ds/dataset/quran/999/0034.mp3
# rename /ds/dataset/quran/999/0035.mp3_tmp to /ds/dataset/quran/999/0035.mp3
# rename /ds/dataset/quran/999/0036.mp3_tmp to /ds/dataset/quran/999/0036.mp3
# rename /ds/dataset/quran/999/0037.mp3_tmp to /ds/dataset/quran/999/0037.mp3
# rename /ds/dataset/quran/999/0038.mp3_tmp to /ds/dataset/quran/999/0038.mp3
# rename /ds/dataset/quran/999/0039.mp3_tmp to /ds/dataset/quran/999/0039.mp3
# rename /ds/dataset/quran/999/0040.mp3_tmp to /ds/dataset/quran/999/0040.mp3
# rename /ds/dataset/quran/999/0041.mp3_tmp to /ds/dataset/quran/999/0041.mp3
# rename /ds/dataset/quran/999/0042.mp3_tmp to /ds/dataset/quran/999/0042.mp3
# rename /ds/dataset/quran/999/0043.mp3_tmp to /ds/dataset/quran/999/0043.mp3
# rename /ds/dataset/quran/999/0044.mp3_tmp to /ds/dataset/quran/999/0044.mp3
# rename /ds/dataset/quran/999/0045.mp3_tmp to /ds/dataset/quran/999/0045.mp3
# rename /ds/dataset/quran/999/0046.mp3_tmp to /ds/dataset/quran/999/0046.mp3
# rename /ds/dataset/quran/999/0047.mp3_tmp to /ds/dataset/quran/999/0047.mp3
# rename /ds/dataset/quran/999/0048.mp3_tmp to /ds/dataset/quran/999/0048.mp3
# rename /ds/dataset/quran/999/0049.mp3_tmp to /ds/dataset/quran/999/0049.mp3
# rename /ds/dataset/quran/999/0050.mp3_tmp to /ds/dataset/quran/999/0050.mp3
# rename /ds/dataset/quran/999/0051.mp3_tmp to /ds/dataset/quran/999/0051.mp3
# rename /ds/dataset/quran/999/0052.mp3_tmp to /ds/dataset/quran/999/0052.mp3
# rename /ds/dataset/quran/999/0053.mp3_tmp to /ds/dataset/quran/999/0053.mp3
# rename /ds/dataset/quran/999/0054.mp3_tmp to /ds/dataset/quran/999/0054.mp3
# rename /ds/dataset/quran/999/0055.mp3_tmp to /ds/dataset/quran/999/0055.mp3
# rename /ds/dataset/quran/999/0056.mp3_tmp to /ds/dataset/quran/999/0056.mp3
# rename /ds/dataset/quran/999/0057.mp3_tmp to /ds/dataset/quran/999/0057.mp3
# rename /ds/dataset/quran/999/0058.mp3_tmp to /ds/dataset/quran/999/0058.mp3
# rename /ds/dataset/quran/999/0059.mp3_tmp to /ds/dataset/quran/999/0059.mp3

# %% [markdown]
# ###### to be continued
# from here we will continue by adding more features
# - splitt the dataset into training and test
# - reshuffle the test and generate a csv description file for test to be used kaggle
